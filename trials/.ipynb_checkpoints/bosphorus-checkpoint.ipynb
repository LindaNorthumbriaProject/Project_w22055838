# %% [raw]
# #basic model with class imblance handled

# %%
import os
import random
import numpy as np
from collections import Counter
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, InputLayer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf
import warnings

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
tf.get_logger().setLevel('ERROR')

# Set seeds for reproducibility
def set_seeds(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()

set_seeds(42)

# Define the path to the dataset folder
dataset_folder = r'/Users/Downloads/linda_trials/3D_images_sorted'

# Function to load images and extract labels
def load_images_and_labels(base_folder):
    images = []
    labels = []
    for label_folder in os.listdir(base_folder):
        label_path = os.path.join(base_folder, label_folder)
        if os.path.isdir(label_path):
            for filename in os.listdir(label_path):
                if filename.endswith('.png'):
                    image_file = os.path.join(label_path, filename)
                    img = Image.open(image_file).convert('L')  # Convert to grayscale
                    img = img.resize((64, 64))  # Resize to 64x64 for consistency
                    img_array = np.array(img) / 255.0  # Normalize pixel values to [0, 1]
                    images.append(img_array)
                    labels.append(label_folder)  # The folder name is the label
    return np.array(images), np.array(labels)

# Load images and labels
images, labels = load_images_and_labels(dataset_folder)
images = images.reshape(-1, 64, 64, 1)  # Reshape for CNN input

# Check for class imbalance
label_counts = Counter(labels)
print("Label distribution:")
for label, count in label_counts.items():
    print(f"{label}: {count} images")

# Convert labels to one-hot encoding
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)
labels_categorical = to_categorical(labels_encoded)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels_categorical, test_size=0.2, random_state=42)

# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_encoded),
    y=labels_encoded
)
class_weights_dict = dict(enumerate(class_weights))

# Define the CNN architecture function
def create_model():
    model = Sequential([
        InputLayer(input_shape=(64, 64, 1)),  # Input layer for 64x64 grayscale images
        Conv2D(32, kernel_size=(3, 3), activation='relu'),  # First convolution layer
        MaxPooling2D(pool_size=(2, 2)),  # First pooling layer
        Conv2D(64, kernel_size=(3, 3), activation='relu'),  # Second convolution layer
        MaxPooling2D(pool_size=(2, 2)),  # Second pooling layer
        Flatten(),  # Flatten the output for the dense layer
        Dense(100, activation='relu'),  # Fully connected layer
        Dense(len(np.unique(labels_encoded)), activation='softmax')  # Output layer with one neuron per class
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Initialize list to store results
results = []

# No data augmentation configuration
config = {
    "shear_range": 0.0,
    "zoom_range": 0.0,
    "rotation_range": 0,
    "width_shift_range": 0.0,
    "height_shift_range": 0.0,
    "horizontal_flip": False
}

print(f"Running configuration: No Data Augmentation")

# Create the model
model = create_model()

# Define data augmentation configuration (with no augmentation)
datagen = ImageDataGenerator(
    shear_range=config["shear_range"],
    zoom_range=config["zoom_range"],
    rotation_range=config["rotation_range"],
    width_shift_range=config["width_shift_range"],
    height_shift_range=config["height_shift_range"],
    horizontal_flip=config["horizontal_flip"]
)

# Fit the data generator to the training data
datagen.fit(X_train)

# Train the model using class weights and the data generator
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32, seed=42),
    validation_data=(X_test, y_test),
    epochs=10,
    class_weight=class_weights_dict,
    verbose=0  # Suppress epoch prints
)

# Evaluate the model and store the results
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
predictions = model.predict(X_test, verbose=0)
predicted_classes = np.argmax(predictions, axis=1)
true_classes = np.argmax(y_test, axis=1)

precision = tf.keras.metrics.Precision()
precision.update_state(true_classes, predicted_classes)
recall = tf.keras.metrics.Recall()
recall.update_state(true_classes, predicted_classes)
f1_score = 2 * (precision.result().numpy() * recall.result().numpy()) / (precision.result().numpy() + recall.result().numpy())

# Store the configuration and results
config_results = {
    'config': 'No Data Augmentation',
    'test_accuracy': test_acc,
    'precision': precision.result().numpy(),
    'recall': recall.result().numpy(),
    'f1_score': f1_score
}

# Print the results for this configuration
print(f"Test Accuracy: {test_acc*100:.2f}%")
print(f"Precision: {precision.result().numpy():.2f}")
print(f"Recall: {recall.result().numpy():.2f}")
print(f"F1 Score: {f1_score:.2f}")
print("="*50)

results.append(config_results)

print("\nSummary of Results:")
for idx, result in enumerate(results):
    print(f"Configuration {idx+1}: {result['config']}")
    print(f"Test Accuracy: {result['test_accuracy']*100:.2f}%")
    print(f"Precision: {result['precision']:.2f}")
    print(f"Recall: {result['recall']:.2f}")
    print(f"F1 Score: {result['f1_score']:.2f}")
    print("="*50)

# Plot accuracy and loss
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Label distribution:
# Happy: 223 images
# Sad: 123 images
# Fear: 71 images
# Surprise: 373 images
# Neutral: 143 images
# Anger: 347 images
# Disgust: 136 images
# Running configuration: No Data Augmentation
# Test Accuracy: 54.93%
# Precision: 0.86
# Recall: 0.95
# F1 Score: 0.90
# ==================================================
#
# Summary of Results:
# Configuration 1: No Data Augmentation
# Test Accuracy: 54.93%
# Precision: 0.86
# Recall: 0.95
# F1 Score: 0.90
# ==================================================

# %%
import os
import random
import numpy as np
from PIL import Image
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, InputLayer
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
import warnings

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
tf.get_logger().setLevel('ERROR')

# Set seeds for reproducibility
def set_seeds(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()

set_seeds(42)

# Define the path to the dataset folder
dataset_folder = r'/Users/Downloads/linda_trials/3D_images_sorted'

# Function to load images and extract labels
def load_images_and_labels(base_folder):
    images = []
    labels = []
    for label_folder in os.listdir(base_folder):
        label_path = os.path.join(base_folder, label_folder)
        if os.path.isdir(label_path):
            for filename in os.listdir(label_path):
                if filename.endswith('.png'):
                    image_file = os.path.join(label_path, filename)
                    img = Image.open(image_file).convert('L')  # Convert to grayscale
                    img = img.resize((64, 64))  # Resize to 64x64 for consistency
                    img_array = np.array(img) / 255.0  # Normalize pixel values to [0, 1]
                    images.append(img_array)
                    labels.append(label_folder)  # The folder name is the label
    return np.array(images), np.array(labels)

# Function to define different augmentation combinations
def get_augmentation_combinations():
    shear_ranges = [0.0, 0.1]
    zoom_ranges = [0.0, 0.1]
    rotation_ranges = [0]
    width_shift_ranges = [0.0, 0.1]
    height_shift_ranges = [0.0, 0.1]
    horizontal_flip_options = [True]
    combinations = list(product(shear_ranges, zoom_ranges, rotation_ranges,
                                width_shift_ranges, height_shift_ranges, horizontal_flip_options))

    return combinations

# Load images and labels
images, labels = load_images_and_labels(dataset_folder)
images = images.reshape(-1, 64, 64, 1)  # Reshape for CNN input

# Check for class imbalance
label_counts = Counter(labels)
print("Label distribution:")
for label, count in label_counts.items():
    print(f"{label}: {count} images")

# Convert labels to one-hot encoding
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)
labels_categorical = to_categorical(labels_encoded)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels_categorical, test_size=0.2, random_state=42)

# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_encoded),
    y=labels_encoded
)
class_weights_dict = dict(enumerate(class_weights))

# Get augmentation combinations
augmentation_combinations = get_augmentation_combinations()

# Initialize list to store results
results = []

# Loop over all combinations
for idx, (shear, zoom, rotation, width_shift, height_shift, h_flip) in enumerate(augmentation_combinations):
    print(f"Running configuration {idx+1}/{len(augmentation_combinations)}")

    # Define the CNN architecture
    model = Sequential([
        InputLayer(input_shape=(64, 64, 1)),  # Input layer for 64x64 grayscale images
        Conv2D(32, kernel_size=(3, 3), activation='relu'),  # First convolution layer
        MaxPooling2D(pool_size=(2, 2)),  # First pooling layer
        Conv2D(64, kernel_size=(3, 3), activation='relu'),  # Second convolution layer
        MaxPooling2D(pool_size=(2, 2)),  # Second pooling layer
        Flatten(),  # Flatten the output for the dense layer
        Dense(100, activation='relu'),  # Fully connected layer
        Dense(len(np.unique(labels_encoded)), activation='softmax')  # Output layer with one neuron per class
    ])

    # Compile the model
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Define data augmentation configuration
    datagen = ImageDataGenerator(
        shear_range=shear,
        zoom_range=zoom,
        rotation_range=rotation,
        width_shift_range=width_shift,
        height_shift_range=height_shift,
        horizontal_flip=h_flip
    )

    # Fit the data generator to the training data
    datagen.fit(X_train)

    # Train the model using class weights and augmented data
    history = model.fit(
        datagen.flow(X_train, y_train, batch_size=32, seed=42),
        validation_data=(X_test, y_test),
        epochs=50,
        class_weight=class_weights_dict,
        verbose=0  # Suppress epoch prints
    )

    # Evaluate the model and store the results
    test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
    predictions = model.predict(X_test, verbose=0)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(y_test, axis=1)

    precision = tf.keras.metrics.Precision()
    precision.update_state(true_classes, predicted_classes)
    recall = tf.keras.metrics.Recall()
    recall.update_state(true_classes, predicted_classes)
    f1_score = 2 * (precision.result().numpy() * recall.result().numpy()) / (precision.result().numpy() + recall.result().numpy())

    # Store the configuration and results
    config_results = {
        'config': {
            'shear_range': shear,
            'zoom_range': zoom,
            'rotation_range': rotation,
            'width_shift_range': width_shift,
            'height_shift_range': height_shift,
            'horizontal_flip': h_flip
        },
        'test_accuracy': test_acc,
        'precision': precision.result().numpy(),
        'recall': recall.result().numpy(),
        'f1_score': f1_score,
        'history': history.history  # Save training history for later plotting
    }

    # Print the results for this configuration
    print(f"Configuration {idx+1}/{len(augmentation_combinations)}: {config_results['config']}")
    print(f"Test Accuracy: {test_acc*100:.2f}%")
    print(f"Precision: {precision.result().numpy():.2f}")
    print(f"Recall: {recall.result().numpy():.2f}")
    print(f"F1 Score: {f1_score:.2f}")
    print("="*50)

    results.append(config_results)

# Sort results by F1 score to find the top 10 configurations
sorted_results = sorted(results, key=lambda x: x['f1_score'], reverse=True)[:10]

print("\nTop 10 Augmentation Configurations:")
for idx, result in enumerate(sorted_results):
    print(f"Rank {idx+1}: {result['config']}")
    print(f"Test Accuracy: {result['test_accuracy']*100:.2f}%")
    print(f"Precision: {result['precision']:.2f}")
    print(f"Recall: {result['recall']:.2f}")
    print(f"F1 Score: {result['f1_score']:.2f}")
    print("="*50)

# Plot the accuracy and loss for the top 10 configurations
for idx, result in enumerate(sorted_results):
    history = result['history']
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Training Accuracy')
    plt.plot(history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Accuracy - Top {idx+1}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Training Loss')
    plt.plot(history['val_loss'], label='Validation Loss')
    plt.title(f'Loss - Top {idx+1}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()
# Out:
# Label distribution:
# Happy: 223 images
# Sad: 123 images
# Fear: 71 images
# Surprise: 373 images
# Neutral: 143 images
# Anger: 347 images
# Disgust: 136 images
# Running configuration 1/16
# Configuration 1/16: {'shear_range': 0.0, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 69.72%
# Precision: 0.93
# Recall: 0.94
# F1 Score: 0.93
# ==================================================
# Running configuration 2/16
# Configuration 2/16: {'shear_range': 0.0, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 69.01%
# Precision: 0.91
# Recall: 0.92
# F1 Score: 0.91
# ==================================================
# Running configuration 3/16
# Configuration 3/16: {'shear_range': 0.0, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 67.25%
# Precision: 0.88
# Recall: 0.94
# F1 Score: 0.91
# ==================================================
# Running configuration 4/16
# Configuration 4/16: {'shear_range': 0.0, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 56.69%
# Precision: 0.87
# Recall: 0.95
# F1 Score: 0.91
# ==================================================
# Running configuration 5/16
# Configuration 5/16: {'shear_range': 0.0, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 68.66%
# Precision: 0.92
# Recall: 0.92
# F1 Score: 0.92
# ==================================================
# Running configuration 6/16
# Configuration 6/16: {'shear_range': 0.0, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 66.20%
# Precision: 0.92
# Recall: 0.94
# F1 Score: 0.93
# ==================================================
# Running configuration 7/16
# Configuration 7/16: {'shear_range': 0.0, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 63.38%
# Precision: 0.88
# Recall: 0.93
# F1 Score: 0.91
# ==================================================
# Running configuration 8/16
# Configuration 8/16: {'shear_range': 0.0, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 57.75%
# Precision: 0.88
# Recall: 0.92
# F1 Score: 0.90
# ==================================================
# Running configuration 9/16
# Configuration 9/16: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 66.20%
# Precision: 0.92
# Recall: 0.93
# F1 Score: 0.92
# ==================================================
# Running configuration 10/16
# Configuration 10/16: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 62.32%
# Precision: 0.90
# Recall: 0.94
# F1 Score: 0.92
# ==================================================
# Running configuration 11/16
# Configuration 11/16: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 56.34%
# Precision: 0.88
# Recall: 0.94
# F1 Score: 0.91
# ==================================================
# Running configuration 12/16
# Configuration 12/16: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 65.49%
# Precision: 0.89
# Recall: 0.95
# F1 Score: 0.92
# ==================================================
# Running configuration 13/16
# Configuration 13/16: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 66.55%
# Precision: 0.92
# Recall: 0.94
# F1 Score: 0.93
# ==================================================
# Running configuration 14/16
# Configuration 14/16: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 62.32%
# Precision: 0.93
# Recall: 0.93
# F1 Score: 0.93
# ==================================================
# Running configuration 15/16
# Configuration 15/16: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 63.03%
# Precision: 0.90
# Recall: 0.95
# F1 Score: 0.92
# ==================================================
# Running configuration 16/16
# Configuration 16/16: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 56.34%
# Precision: 0.90
# Recall: 0.89
# F1 Score: 0.89
# ==================================================
#
# Top 10 Augmentation Configurations:
# Rank 1: {'shear_range': 0.0, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 69.72%
# Precision: 0.93
# Recall: 0.94
# F1 Score: 0.93
# ==================================================
# Rank 2: {'shear_range': 0.0, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 66.20%
# Precision: 0.92
# Recall: 0.94
# F1 Score: 0.93
# ==================================================
# Rank 3: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 66.55%
# Precision: 0.92
# Recall: 0.94
# F1 Score: 0.93
# ==================================================
# Rank 4: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 62.32%
# Precision: 0.93
# Recall: 0.93
# F1 Score: 0.93
# ==================================================
# Rank 5: {'shear_range': 0.1, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 63.03%
# Precision: 0.90
# Recall: 0.95
# F1 Score: 0.92
# ==================================================
# Rank 6: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 66.20%
# Precision: 0.92
# Recall: 0.93
# F1 Score: 0.92
# ==================================================
# Rank 7: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 62.32%
# Precision: 0.90
# Recall: 0.94
# F1 Score: 0.92
# ==================================================
# Rank 8: {'shear_range': 0.0, 'zoom_range': 0.1, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.0, 'horizontal_flip': True}
# Test Accuracy: 68.66%
# Precision: 0.92
# Recall: 0.92
# F1 Score: 0.92
# ==================================================
# Rank 9: {'shear_range': 0.1, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.1, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 65.49%
# Precision: 0.89
# Recall: 0.95
# F1 Score: 0.92
# ==================================================
# Rank 10: {'shear_range': 0.0, 'zoom_range': 0.0, 'rotation_range': 0, 'width_shift_range': 0.0, 'height_shift_range': 0.1, 'horizontal_flip': True}
# Test Accuracy: 69.01%
# Precision: 0.91
# Recall: 0.92
# F1 Score: 0.91
# ==================================================

# %% [raw]
# # code for optimization

# %%
import os
import random
import numpy as np
from PIL import Image
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, InputLayer
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import tensorflow as tf
from itertools import product
import warnings

# Suppress warnings
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
tf.get_logger().setLevel('ERROR')

# Set seeds for reproducibility
def set_seeds(seed=42):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)
    tf.keras.utils.set_random_seed(seed)
    tf.config.experimental.enable_op_determinism()

set_seeds(42)

# Define the path to the dataset folder
dataset_folder = r'/Users/Downloads/linda_trials/3D_images_sorted'

# Function to load images and extract labels
def load_images_and_labels(base_folder):
    images = []
    labels = []
    for label_folder in os.listdir(base_folder):
        label_path = os.path.join(base_folder, label_folder)
        if os.path.isdir(label_path):
            for filename in os.listdir(label_path):
                if filename.endswith('.png'):
                    image_file = os.path.join(label_path, filename)
                    img = Image.open(image_file).convert('L')  # Convert to grayscale
                    img = img.resize((64, 64))  # Resize to 64x64 for consistency
                    img_array = np.array(img) / 255.0  # Normalize pixel values to [0, 1]
                    images.append(img_array)
                    labels.append(label_folder)  # The folder name is the label
    return np.array(images), np.array(labels)

# Load images and labels
try:
    images, labels = load_images_and_labels(dataset_folder)
    images = images.reshape(-1, 64, 64, 1)  # Reshape for CNN input
except Exception as e:
    print(f"Error loading images: {e}")

# Convert labels to one-hot encoding
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)
labels_categorical = to_categorical(labels_encoded)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels_categorical, test_size=0.2, random_state=42)


# Calculate class weights
class_weights = class_weight.compute_class_weight(
    class_weight='balanced',
    classes=np.unique(labels_encoded),
    y=labels_encoded
)
class_weights_dict = dict(enumerate(class_weights))

# Data augmentation generator
data_gen = ImageDataGenerator(
    shear_range=0.0,
    zoom_range=0.0,
    rotation_range=0,
    width_shift_range=0.0,
    height_shift_range=0.0,
    horizontal_flip=True
)

# Configuration options
parameter_combinations = list(product(
    [1, 2],          # conv_layers
    [32, 64],        # filters
    [1, 2],          # dense_layers
    [64, 128],       # dense_units
    [0.1, 0.2, 0.3], # dropout
    [50],            # epochs
    [32, 64],        # batch_size
    [0.001, 0.002],  # learning_rate
    ['relu'],        # activation
    ['adam']  # optimizer
))

# Loop over configurations
config_results = []

for idx, (conv_layers, filters, dense_layers, dense_units, dropout, epochs, batch_size, learning_rate, activation, optimizer) in enumerate(parameter_combinations):
    try:
        print(f"Running configuration {idx+1}/{len(parameter_combinations)}")
        model = Sequential()
        model.add(InputLayer(input_shape=(64, 64, 1)))
        for _ in range(conv_layers):
            model.add(Conv2D(filters, kernel_size=(3, 3), activation=activation))
            model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Flatten())
        for _ in range(dense_layers):
            model.add(Dense(dense_units, activation=activation))
            model.add(Dropout(dropout))
        model.add(Dense(len(np.unique(labels_encoded)), activation='softmax'))

        if optimizer == 'adam':
            optimizer_instance = Adam(learning_rate=learning_rate)
        else:
            optimizer_instance = SGD(learning_rate=learning_rate)
        model.compile(optimizer=optimizer_instance, loss='categorical_crossentropy', metrics=['accuracy'])

        # Train with data augmentation
        train_gen = data_gen.flow(X_train, y_train, batch_size=batch_size)
        history = model.fit(train_gen, epochs=epochs, validation_data=(X_test, y_test), class_weight=class_weights_dict, verbose=0)

        # Evaluate
        test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
        predictions = model.predict(X_test, verbose=0)
        predicted_classes = np.argmax(predictions, axis=1)
        true_classes = np.argmax(y_test, axis=1)

        precision = tf.keras.metrics.Precision()
        precision.update_state(true_classes, predicted_classes)
        recall = tf.keras.metrics.Recall()
        recall.update_state(true_classes, predicted_classes)
        f1_score = 2 * (precision.result().numpy() * recall.result().numpy()) / (precision.result().numpy() + recall.result().numpy())

        config_results.append({
            'config': {
                'conv_layers': conv_layers,
                'filters': filters,
                'dense_layers': dense_layers,
                'dense_units': dense_units,
                'dropout': dropout,
                'epochs': epochs,
                'batch_size': batch_size,
                'learning_rate': learning_rate,
                'activation': activation,
                'optimizer': optimizer
            },
            'test_accuracy': test_acc,
            'precision': precision.result().numpy(),
            'recall': recall.result().numpy(),
            'f1_score': f1_score,
            'history': history
        })

        # Print current configuration results
        print(config_results[-1])
    except Exception as e:
        print(f"Failed to run configuration {idx+1} due to: {e}")

# Additional code for sorting and plotting the top 15 configurations as required can be added here if necessary
# Sort the results based on F1-score in descending order
sorted_results = sorted(config_results, key=lambda x: x['f1_score'], reverse=True)

# Get the top 15 configurations
top_15_configs = sorted_results[:15]

# Extracting details for plotting
f1_scores = [result['f1_score'] for result in top_15_configs]
config_labels = [f"Config {i+1}" for i in range(15)]

# Plotting the top 15 configurations based on F1 score
plt.figure(figsize=(12, 6))
plt.bar(config_labels, f1_scores, color='skyblue')
plt.xlabel('Configuration')
plt.ylabel('F1 Score')
plt.title('Top 15 Configurations by F1 Score')
plt.xticks(rotation=45)
plt.tight_layout()  # Adjust layout to make room for rotated x-axis labels
plt.show()

# Optionally, print out details of the top 15 configurations
for idx, result in enumerate(top_15_configs):
    config_details = result['config']
    print(f"Top {idx+1} Configuration:")
    print(f"Config Details: {config_details}")
    print(f"Test Accuracy: {result['test_accuracy']:.4f}, Precision: {result['precision']:.4f}, Recall: {result['recall']:.4f}, F1 Score: {result['f1_score']:.4f}\n")
# Out:
# Running configuration 1/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6161971688270569, 'precision': 0.8918919, 'recall': 0.9339623, 'f1_score': 0.9124424023308387, 'history': <keras.src.callbacks.history.History object at 0x294e85fc0>}
# Running configuration 2/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6443662047386169, 'precision': 0.90909094, 'recall': 0.8962264, 'f1_score': 0.9026128327203333, 'history': <keras.src.callbacks.history.History object at 0x29605ceb0>}
# Running configuration 3/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.22887323796749115, 'precision': 0.76383764, 'recall': 0.9764151, 'f1_score': 0.8571428669287338, 'history': <keras.src.callbacks.history.History object at 0x295cd3fa0>}
# Running configuration 4/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5845070481300354, 'precision': 0.85833335, 'recall': 0.9716981, 'f1_score': 0.9115044501432311, 'history': <keras.src.callbacks.history.History object at 0x2961f8100>}
# Running configuration 5/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.8535565, 'recall': 0.9622642, 'f1_score': 0.9046563702386416, 'history': <keras.src.callbacks.history.History object at 0x296ce6f80>}
# Running configuration 6/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5704225301742554, 'precision': 0.8493724, 'recall': 0.9575472, 'f1_score': 0.90022173782817, 'history': <keras.src.callbacks.history.History object at 0x2950990f0>}
# Running configuration 7/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.4190140962600708, 'precision': 0.78039217, 'recall': 0.9386792, 'f1_score': 0.8522484060320308, 'history': <keras.src.callbacks.history.History object at 0x295fbc580>}
# Running configuration 8/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.7007042169570923, 'precision': 0.9201878, 'recall': 0.9245283, 'f1_score': 0.9223529525803575, 'history': <keras.src.callbacks.history.History object at 0x29998bf70>}
# Running configuration 9/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5035211443901062, 'precision': 0.83760685, 'recall': 0.9245283, 'f1_score': 0.8789237701531627, 'history': <keras.src.callbacks.history.History object at 0x299ffcdf0>}
# Running configuration 10/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.9056604, 'recall': 0.9056604, 'f1_score': 0.9056604183366832, 'history': <keras.src.callbacks.history.History object at 0x29fe1fbe0>}
# Running configuration 11/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.14436618983745575, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x29519bb20>}
# Running configuration 12/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6021126508712769, 'precision': 0.86864406, 'recall': 0.9669811, 'f1_score': 0.9151785841850485, 'history': <keras.src.callbacks.history.History object at 0x2a069fb80>}
# Running configuration 13/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6936619877815247, 'precision': 0.8938053, 'recall': 0.9528302, 'f1_score': 0.9223744023995814, 'history': <keras.src.callbacks.history.History object at 0x2a0e3b1c0>}
# Running configuration 14/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.8691983, 'recall': 0.9716981, 'f1_score': 0.9175946757007486, 'history': <keras.src.callbacks.history.History object at 0x29526a3b0>}
# Running configuration 15/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.89686096, 'recall': 0.9433962, 'f1_score': 0.9195401807426685, 'history': <keras.src.callbacks.history.History object at 0x2c89e54e0>}
# Running configuration 16/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.8903509, 'recall': 0.9575472, 'f1_score': 0.9227272797648093, 'history': <keras.src.callbacks.history.History object at 0x2d8926680>}
# Running configuration 17/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.88235295, 'recall': 0.9198113, 'f1_score': 0.9006928325500326, 'history': <keras.src.callbacks.history.History object at 0x2e2e4d810>}
# Running configuration 18/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6091549396514893, 'precision': 0.88839287, 'recall': 0.9386792, 'f1_score': 0.9128440295141934, 'history': <keras.src.callbacks.history.History object at 0x2e339a740>}
# Running configuration 19/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6302816867828369, 'precision': 0.9174312, 'recall': 0.9433962, 'f1_score': 0.9302325238735375, 'history': <keras.src.callbacks.history.History object at 0x2e30539d0>}
# Running configuration 20/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6091549396514893, 'precision': 0.87445885, 'recall': 0.9528302, 'f1_score': 0.9119638746662081, 'history': <keras.src.callbacks.history.History object at 0x2e7bc5150>}
# Running configuration 21/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6056337952613831, 'precision': 0.8839286, 'recall': 0.9339623, 'f1_score': 0.9082569126193296, 'history': <keras.src.callbacks.history.History object at 0x2e7edbac0>}
# Running configuration 22/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6091549396514893, 'precision': 0.876652, 'recall': 0.9386792, 'f1_score': 0.906605892185382, 'history': <keras.src.callbacks.history.History object at 0x311ec7160>}
# Running configuration 23/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6161971688270569, 'precision': 0.8826087, 'recall': 0.9575472, 'f1_score': 0.9185520977568137, 'history': <keras.src.callbacks.history.History object at 0x3203ae320>}
# Running configuration 24/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.672535240650177, 'precision': 0.912037, 'recall': 0.9292453, 'f1_score': 0.9205607143846779, 'history': <keras.src.callbacks.history.History object at 0x326d994b0>}
# Running configuration 25/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5598591566085815, 'precision': 0.8259109, 'recall': 0.9622642, 'f1_score': 0.8888888888888888, 'history': <keras.src.callbacks.history.History object at 0x32bd438e0>}
# Running configuration 26/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.923445, 'recall': 0.9103774, 'f1_score': 0.9168645934072177, 'history': <keras.src.callbacks.history.History object at 0x331623eb0>}
# Running configuration 27/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6936619877815247, 'precision': 0.9223744, 'recall': 0.9528302, 'f1_score': 0.9373550096386885, 'history': <keras.src.callbacks.history.History object at 0x3320d4a90>}
# Running configuration 28/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6690140962600708, 'precision': 0.8942731, 'recall': 0.9575472, 'f1_score': 0.9248291865030139, 'history': <keras.src.callbacks.history.History object at 0x336f60b50>}
# Running configuration 29/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.48591548204421997, 'precision': 0.8489796, 'recall': 0.9811321, 'f1_score': 0.9102844628972342, 'history': <keras.src.callbacks.history.History object at 0x337449390>}
# Running configuration 30/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.591549277305603, 'precision': 0.89400923, 'recall': 0.9150943, 'f1_score': 0.904428941753548, 'history': <keras.src.callbacks.history.History object at 0x3427d1960>}
# Running configuration 31/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5352112650871277, 'precision': 0.80237156, 'recall': 0.9575472, 'f1_score': 0.8731183366717993, 'history': <keras.src.callbacks.history.History object at 0x343e2c670>}
# Running configuration 32/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.44014084339141846, 'precision': 0.88095236, 'recall': 0.8726415, 'f1_score': 0.8767772347536528, 'history': <keras.src.callbacks.history.History object at 0x34773b910>}
# Running configuration 33/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5633803009986877, 'precision': 0.84166664, 'recall': 0.9528302, 'f1_score': 0.893805357352825, 'history': <keras.src.callbacks.history.History object at 0x29373be80>}
# Running configuration 34/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6126760840415955, 'precision': 0.9078341, 'recall': 0.9292453, 'f1_score': 0.918414923709028, 'history': <keras.src.callbacks.history.History object at 0x293b6c700>}
# Running configuration 35/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5, 'precision': 0.8445378, 'recall': 0.9481132, 'f1_score': 0.8933333271267707, 'history': <keras.src.callbacks.history.History object at 0x29466eb60>}
# Running configuration 36/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.3802816867828369, 'precision': 0.7565543, 'recall': 0.9528302, 'f1_score': 0.8434238608763183, 'history': <keras.src.callbacks.history.History object at 0x31c7cdea0>}
# Running configuration 37/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.8995434, 'recall': 0.9292453, 'f1_score': 0.9141531395101438, 'history': <keras.src.callbacks.history.History object at 0x2888d65f0>}
# Running configuration 38/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.92537314, 'recall': 0.8773585, 'f1_score': 0.9007263988164849, 'history': <keras.src.callbacks.history.History object at 0x31e4c0970>}
# Running configuration 39/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.658450722694397, 'precision': 0.8893805, 'recall': 0.9481132, 'f1_score': 0.9178082360636236, 'history': <keras.src.callbacks.history.History object at 0x28899f910>}
# Running configuration 40/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6795774698257446, 'precision': 0.9056604, 'recall': 0.9056604, 'f1_score': 0.9056604183366832, 'history': <keras.src.callbacks.history.History object at 0x35fe984c0>}
# Running configuration 41/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.7007042169570923, 'precision': 0.925, 'recall': 0.8726415, 'f1_score': 0.8980582517833566, 'history': <keras.src.callbacks.history.History object at 0x2933ac9a0>}
# Running configuration 42/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6478873491287231, 'precision': 0.91346157, 'recall': 0.8962264, 'f1_score': 0.9047619016251027, 'history': <keras.src.callbacks.history.History object at 0x293458c40>}
# Running configuration 43/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.35563379526138306, 'precision': 0.78294575, 'recall': 0.9528302, 'f1_score': 0.8595744832818982, 'history': <keras.src.callbacks.history.History object at 0x387b73b50>}
# Running configuration 44/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.9082569, 'recall': 0.9339623, 'f1_score': 0.9209302861316813, 'history': <keras.src.callbacks.history.History object at 0x38de2ff40>}
# Running configuration 45/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.87606835, 'recall': 0.9669811, 'f1_score': 0.919282473794712, 'history': <keras.src.callbacks.history.History object at 0x3933e8730>}
# Running configuration 46/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.4577464759349823, 'precision': 0.8097166, 'recall': 0.9433962, 'f1_score': 0.8714596506936949, 'history': <keras.src.callbacks.history.History object at 0x397d6c910>}
# Running configuration 47/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5985915660858154, 'precision': 0.923445, 'recall': 0.9103774, 'f1_score': 0.9168645934072177, 'history': <keras.src.callbacks.history.History object at 0x39a2c7850>}
# Running configuration 48/192
# {'config': {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6408450603485107, 'precision': 0.9, 'recall': 0.9339623, 'f1_score': 0.9166666991671428, 'history': <keras.src.callbacks.history.History object at 0x39dc4bfa0>}
# Running configuration 49/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6338028311729431, 'precision': 0.91079813, 'recall': 0.9150943, 'f1_score': 0.9129411460539532, 'history': <keras.src.callbacks.history.History object at 0x3a36cf520>}
# Running configuration 50/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6901408433914185, 'precision': 0.9264706, 'recall': 0.8915094, 'f1_score': 0.9086537976050604, 'history': <keras.src.callbacks.history.History object at 0x3af39bbb0>}
# Running configuration 51/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5598591566085815, 'precision': 0.876652, 'recall': 0.9386792, 'f1_score': 0.906605892185382, 'history': <keras.src.callbacks.history.History object at 0x3b47a5870>}
# Running configuration 52/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.91943127, 'recall': 0.9150943, 'f1_score': 0.9172576904352401, 'history': <keras.src.callbacks.history.History object at 0x3933e8970>}
# Running configuration 53/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.9086758, 'recall': 0.9386792, 'f1_score': 0.9234338815971388, 'history': <keras.src.callbacks.history.History object at 0x3c007fe20>}
# Running configuration 54/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.9, 'recall': 0.9764151, 'f1_score': 0.936651607857687, 'history': <keras.src.callbacks.history.History object at 0x3cb23c9d0>}
# Running configuration 55/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.08802817016839981, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x3d0d13760>}
# Running configuration 56/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5281690359115601, 'precision': 0.8119658, 'recall': 0.8962264, 'f1_score': 0.8520179728955002, 'history': <keras.src.callbacks.history.History object at 0x3d6c5e950>}
# Running configuration 57/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.4119718372821808, 'precision': 0.7765151, 'recall': 0.9669811, 'f1_score': 0.8613445579250386, 'history': <keras.src.callbacks.history.History object at 0x37f855ae0>}
# Running configuration 58/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6408450603485107, 'precision': 0.9004525, 'recall': 0.9386792, 'f1_score': 0.9191686023015014, 'history': <keras.src.callbacks.history.History object at 0x350004c70>}
# Running configuration 59/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.40140846371650696, 'precision': 0.74822694, 'recall': 0.995283, 'f1_score': 0.8542509850179363, 'history': <keras.src.callbacks.history.History object at 0x3503d79d0>}
# Running configuration 60/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5563380122184753, 'precision': 0.86160713, 'recall': 0.9103774, 'f1_score': 0.8853210780811497, 'history': <keras.src.callbacks.history.History object at 0x35537af50>}
# Running configuration 61/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6443662047386169, 'precision': 0.9004525, 'recall': 0.9386792, 'f1_score': 0.9191686023015014, 'history': <keras.src.callbacks.history.History object at 0x357d2e0e0>}
# Running configuration 62/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.9186603, 'recall': 0.9056604, 'f1_score': 0.9121140240301719, 'history': <keras.src.callbacks.history.History object at 0x3da5b92a0>}
# Running configuration 63/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6408450603485107, 'precision': 0.9138756, 'recall': 0.9009434, 'f1_score': 0.9073634350939204, 'history': <keras.src.callbacks.history.History object at 0x3dad2c430>}
# Running configuration 64/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.9116279, 'recall': 0.9245283, 'f1_score': 0.9180327932711428, 'history': <keras.src.callbacks.history.History object at 0x3f787f5b0>}
# Running configuration 65/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6549295783042908, 'precision': 0.92488265, 'recall': 0.9292453, 'f1_score': 0.92705884803677, 'history': <keras.src.callbacks.history.History object at 0x3f7d22770>}
# Running configuration 66/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6866196990013123, 'precision': 0.9227053, 'recall': 0.9009434, 'f1_score': 0.9116945269649888, 'history': <keras.src.callbacks.history.History object at 0x41843d900>}
# Running configuration 67/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6126760840415955, 'precision': 0.8695652, 'recall': 0.9433962, 'f1_score': 0.9049773865741834, 'history': <keras.src.callbacks.history.History object at 0x420220a90>}
# Running configuration 68/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6830986142158508, 'precision': 0.9124424, 'recall': 0.9339623, 'f1_score': 0.923076952875197, 'history': <keras.src.callbacks.history.History object at 0x4208c39a0>}
# Running configuration 69/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6338028311729431, 'precision': 0.8918919, 'recall': 0.9339623, 'f1_score': 0.9124424023308387, 'history': <keras.src.callbacks.history.History object at 0x4272aaf20>}
# Running configuration 70/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.92788464, 'recall': 0.9103774, 'f1_score': 0.9190476159595757, 'history': <keras.src.callbacks.history.History object at 0x42f1a20e0>}
# Running configuration 71/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.8956522, 'recall': 0.9716981, 'f1_score': 0.9321266535031189, 'history': <keras.src.callbacks.history.History object at 0x440949270>}
# Running configuration 72/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.8893805, 'recall': 0.9481132, 'f1_score': 0.9178082360636236, 'history': <keras.src.callbacks.history.History object at 0x3f789cbb0>}
# Running configuration 73/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6302816867828369, 'precision': 0.9128205, 'recall': 0.8396226, 'f1_score': 0.8746929198197783, 'history': <keras.src.callbacks.history.History object at 0x3bd60eb90>}
# Running configuration 74/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.672535240650177, 'precision': 0.9201878, 'recall': 0.9245283, 'f1_score': 0.9223529525803575, 'history': <keras.src.callbacks.history.History object at 0x3d809ef80>}
# Running configuration 75/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.9142857, 'recall': 0.9056604, 'f1_score': 0.9099526594088327, 'history': <keras.src.callbacks.history.History object at 0x3be098550>}
# Running configuration 76/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.91121495, 'recall': 0.9198113, 'f1_score': 0.9154928963092006, 'history': <keras.src.callbacks.history.History object at 0x453fd62c0>}
# Running configuration 77/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6901408433914185, 'precision': 0.9212963, 'recall': 0.9386792, 'f1_score': 0.9299065168985232, 'history': <keras.src.callbacks.history.History object at 0x45d1616c0>}
# Running configuration 78/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.9116279, 'recall': 0.9245283, 'f1_score': 0.9180327932711428, 'history': <keras.src.callbacks.history.History object at 0x45f5e5e10>}
# Running configuration 79/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.3309859037399292, 'precision': 0.76717556, 'recall': 0.9481132, 'f1_score': 0.8481012253555436, 'history': <keras.src.callbacks.history.History object at 0x468e8bf40>}
# Running configuration 80/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6056337952613831, 'precision': 0.8410042, 'recall': 0.9481132, 'f1_score': 0.8913525562419061, 'history': <keras.src.callbacks.history.History object at 0x46d230850>}
# Running configuration 81/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.47887325286865234, 'precision': 0.84016395, 'recall': 0.9669811, 'f1_score': 0.8991228035456738, 'history': <keras.src.callbacks.history.History object at 0x47271faf0>}
# Running configuration 82/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.08802817016839981, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x474c07f70>}
# Running configuration 83/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.26408451795578003, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x474ff7dc0>}
# Running configuration 84/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.15140844881534576, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x48384ac50>}
# Running configuration 85/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6830986142158508, 'precision': 0.9041096, 'recall': 0.9339623, 'f1_score': 0.9187935635206329, 'history': <keras.src.callbacks.history.History object at 0x488bb1f90>}
# Running configuration 86/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6690140962600708, 'precision': 0.91588783, 'recall': 0.9245283, 'f1_score': 0.9201877380812811, 'history': <keras.src.callbacks.history.History object at 0x4984726e0>}
# Running configuration 87/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.9303483, 'recall': 0.8820755, 'f1_score': 0.9055690478746243, 'history': <keras.src.callbacks.history.History object at 0x499a76c20>}
# Running configuration 88/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6690140962600708, 'precision': 0.9326923, 'recall': 0.9150943, 'f1_score': 0.923809501690219, 'history': <keras.src.callbacks.history.History object at 0x4a7689090>}
# Running configuration 89/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6549295783042908, 'precision': 0.9230769, 'recall': 0.9056604, 'f1_score': 0.9142857235980955, 'history': <keras.src.callbacks.history.History object at 0x4a7dcbf40>}
# Running configuration 90/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6549295783042908, 'precision': 0.9326923, 'recall': 0.9150943, 'f1_score': 0.923809501690219, 'history': <keras.src.callbacks.history.History object at 0x485e74b20>}
# Running configuration 91/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6091549396514893, 'precision': 0.9026549, 'recall': 0.9622642, 'f1_score': 0.9315068484394251, 'history': <keras.src.callbacks.history.History object at 0x48625e2f0>}
# Running configuration 92/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6478873491287231, 'precision': 0.913242, 'recall': 0.9433962, 'f1_score': 0.9280742182308257, 'history': <keras.src.callbacks.history.History object at 0x487db7490>}
# Running configuration 93/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6021126508712769, 'precision': 0.852459, 'recall': 0.9811321, 'f1_score': 0.9122806903484022, 'history': <keras.src.callbacks.history.History object at 0x288221630>}
# Running configuration 94/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6267605423927307, 'precision': 0.91549295, 'recall': 0.9198113, 'f1_score': 0.9176470519461084, 'history': <keras.src.callbacks.history.History object at 0x4d81e3a00>}
# Running configuration 95/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5809859037399292, 'precision': 0.8669725, 'recall': 0.8915094, 'f1_score': 0.8790697661806322, 'history': <keras.src.callbacks.history.History object at 0x4e03fba30>}
# Running configuration 96/192
# {'config': {'conv_layers': 1, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6443662047386169, 'precision': 0.8942731, 'recall': 0.9575472, 'f1_score': 0.9248291865030139, 'history': <keras.src.callbacks.history.History object at 0x4e09dfa60>}
# Running configuration 97/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6478873491287231, 'precision': 0.88744587, 'recall': 0.9669811, 'f1_score': 0.9255078776047484, 'history': <keras.src.callbacks.history.History object at 0x4ef4a7f10>}
# Running configuration 98/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6408450603485107, 'precision': 0.9116279, 'recall': 0.9245283, 'f1_score': 0.9180327932711428, 'history': <keras.src.callbacks.history.History object at 0x28840f850>}
# Running configuration 99/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6690140962600708, 'precision': 0.91588783, 'recall': 0.9245283, 'f1_score': 0.9201877380812811, 'history': <keras.src.callbacks.history.History object at 0x4f0dae050>}
# Running configuration 100/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6866196990013123, 'precision': 0.9150943, 'recall': 0.9150943, 'f1_score': 0.9150943463819313, 'history': <keras.src.callbacks.history.History object at 0x4f7909c00>}
# Running configuration 101/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6690140962600708, 'precision': 0.94634145, 'recall': 0.9150943, 'f1_score': 0.930455646241992, 'history': <keras.src.callbacks.history.History object at 0x507ead240>}
# Running configuration 102/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6267605423927307, 'precision': 0.87772924, 'recall': 0.9481132, 'f1_score': 0.9115646649355235, 'history': <keras.src.callbacks.history.History object at 0x5101ff940>}
# Running configuration 103/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6408450603485107, 'precision': 0.95098037, 'recall': 0.9150943, 'f1_score': 0.9326923119920831, 'history': <keras.src.callbacks.history.History object at 0x510e5b550>}
# Running configuration 104/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6654929518699646, 'precision': 0.9368932, 'recall': 0.9103774, 'f1_score': 0.9234449677397997, 'history': <keras.src.callbacks.history.History object at 0x516fcabc0>}
# Running configuration 105/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6619718074798584, 'precision': 0.93301433, 'recall': 0.9198113, 'f1_score': 0.9263657986281342, 'history': <keras.src.callbacks.history.History object at 0x5197dd360>}
# Running configuration 106/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6338028311729431, 'precision': 0.8959276, 'recall': 0.9339623, 'f1_score': 0.9145496787051189, 'history': <keras.src.callbacks.history.History object at 0x3b7f40f10>}
# Running configuration 107/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.658450722694397, 'precision': 0.8986784, 'recall': 0.9622642, 'f1_score': 0.929384990491789, 'history': <keras.src.callbacks.history.History object at 0x3bca58550>}
# Running configuration 108/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6795774698257446, 'precision': 0.92957747, 'recall': 0.9339623, 'f1_score': 0.9317647383937979, 'history': <keras.src.callbacks.history.History object at 0x3b8036d40>}
# Running configuration 109/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6901408433914185, 'precision': 0.94258374, 'recall': 0.9292453, 'f1_score': 0.935866995626046, 'history': <keras.src.callbacks.history.History object at 0x47a4e28f0>}
# Running configuration 110/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6443662047386169, 'precision': 0.9146919, 'recall': 0.9103774, 'f1_score': 0.9125295701293374, 'history': <keras.src.callbacks.history.History object at 0x3b8169f30>}
# Running configuration 111/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.658450722694397, 'precision': 0.9292453, 'recall': 0.9292453, 'f1_score': 0.9292453202339503, 'history': <keras.src.callbacks.history.History object at 0x4818a86d0>}
# Running configuration 112/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6408450603485107, 'precision': 0.9052133, 'recall': 0.9009434, 'f1_score': 0.9030733000949104, 'history': <keras.src.callbacks.history.History object at 0x47a673f10>}
# Running configuration 113/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6936619877815247, 'precision': 0.90178573, 'recall': 0.9528302, 'f1_score': 0.9266055417381267, 'history': <keras.src.callbacks.history.History object at 0x516dab820>}
# Running configuration 114/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.9146919, 'recall': 0.9103774, 'f1_score': 0.9125295701293374, 'history': <keras.src.callbacks.history.History object at 0x519e22020>}
# Running configuration 115/192
# {'config': {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6936619877815247, 'precision': 0.93779904, 'recall': 0.9245283, 'f1_score': 0.9311163748003339, 'history': <keras.src.callbacks.history.History object at 0x52ddc5c30>}
# Running configuration 116/192
# ...
# Running configuration 166/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6338028311729431, 'precision': 0.9036697, 'recall': 0.9292453, 'f1_score': 0.9162790721874637, 'history': <keras.src.callbacks.history.History object at 0x5dadc6320>}
# Running configuration 167/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6795774698257446, 'precision': 0.94974875, 'recall': 0.8915094, 'f1_score': 0.9197080358131928, 'history': <keras.src.callbacks.history.History object at 0x5db430ac0>}
# Running configuration 168/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6373239159584045, 'precision': 0.9205608, 'recall': 0.9292453, 'f1_score': 0.9248826696503476, 'history': <keras.src.callbacks.history.History object at 0x5dee28670>}
# Running configuration 169/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6866196990013123, 'precision': 0.9223744, 'recall': 0.9528302, 'f1_score': 0.9373550096386885, 'history': <keras.src.callbacks.history.History object at 0x5df4d74c0>}
# Running configuration 170/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.14436618983745575, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x5dfcf3910>}
# Running configuration 171/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6654929518699646, 'precision': 0.88646287, 'recall': 0.9575472, 'f1_score': 0.9206349113996685, 'history': <keras.src.callbacks.history.History object at 0x5f50a1b40>}
# Running configuration 172/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6021126508712769, 'precision': 0.8669528, 'recall': 0.9528302, 'f1_score': 0.907865187823533, 'history': <keras.src.callbacks.history.History object at 0x5f7022050>}
# Running configuration 173/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6232394576072693, 'precision': 0.9058296, 'recall': 0.9528302, 'f1_score': 0.9287356473704248, 'history': <keras.src.callbacks.history.History object at 0x4f3cba4d0>}
# Running configuration 174/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.14436618983745575, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x4f6e206a0>}
# Running configuration 175/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6830986142158508, 'precision': 0.91402715, 'recall': 0.9528302, 'f1_score': 0.9330254386656122, 'history': <keras.src.callbacks.history.History object at 0x4f6e20a30>}
# Running configuration 176/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6197183132171631, 'precision': 0.8986784, 'recall': 0.9622642, 'f1_score': 0.929384990491789, 'history': <keras.src.callbacks.history.History object at 0x5f8b00f70>}
# Running configuration 177/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6795774698257446, 'precision': 0.9013453, 'recall': 0.9481132, 'f1_score': 0.9241379385914309, 'history': <keras.src.callbacks.history.History object at 0x5fd5a7100>}
# Running configuration 178/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.04929577559232712, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x60035b1c0>}
# Running configuration 179/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5985915660858154, 'precision': 0.8717949, 'recall': 0.9622642, 'f1_score': 0.9147982587423942, 'history': <keras.src.callbacks.history.History object at 0x58de3da50>}
# Running configuration 180/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.5492957830429077, 'precision': 0.9198113, 'recall': 0.9198113, 'f1_score': 0.9198112892712376, 'history': <keras.src.callbacks.history.History object at 0x6028c2c50>}
# Running configuration 181/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6514084339141846, 'precision': 0.92488265, 'recall': 0.9292453, 'f1_score': 0.92705884803677, 'history': <keras.src.callbacks.history.History object at 0x604af0e20>}
# Running configuration 182/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6056337952613831, 'precision': 0.9386792, 'recall': 0.9386792, 'f1_score': 0.938679197359685, 'history': <keras.src.callbacks.history.History object at 0x608329cc0>}
# Running configuration 183/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.7112675905227661, 'precision': 0.943662, 'recall': 0.9481132, 'f1_score': 0.9458823796296764, 'history': <keras.src.callbacks.history.History object at 0x608d7f610>}
# Running configuration 184/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6795774698257446, 'precision': 0.9189189, 'recall': 0.9622642, 'f1_score': 0.9400921694029115, 'history': <keras.src.callbacks.history.History object at 0x60b29a890>}
# Running configuration 185/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.921659, 'recall': 0.9433962, 'f1_score': 0.9324009376156304, 'history': <keras.src.callbacks.history.History object at 0x60caee680>}
# Running configuration 186/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.08802817016839981, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x60f18fb50>}
# Running configuration 187/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.9292453, 'recall': 0.9292453, 'f1_score': 0.9292453202339503, 'history': <keras.src.callbacks.history.History object at 0x60fa46410>}
# Running configuration 188/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6232394576072693, 'precision': 0.8649789, 'recall': 0.9669811, 'f1_score': 0.9131403393400425, 'history': <keras.src.callbacks.history.History object at 0x60fe95b40>}
# Running configuration 189/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6654929518699646, 'precision': 0.9009009, 'recall': 0.9433962, 'f1_score': 0.9216589578779408, 'history': <keras.src.callbacks.history.History object at 0x61ccb0f40>}
# Running configuration 190/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.08802817016839981, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x61fa0f0d0>}
# Running configuration 191/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.6760563254356384, 'precision': 0.9045454, 'recall': 0.9386792, 'f1_score': 0.9212962750376097, 'history': <keras.src.callbacks.history.History object at 0x61fa222f0>}
# Running configuration 192/192
# {'config': {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}, 'test_accuracy': 0.14436618983745575, 'precision': 0.74647886, 'recall': 1.0, 'f1_score': 0.8548387272921122, 'history': <keras.src.callbacks.history.History object at 0x6330e1c00>}
# Top 1 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.7113, Precision: 0.9437, Recall: 0.9481, F1 Score: 0.9459
#
# Top 2 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6796, Precision: 0.9189, Recall: 0.9623, F1 Score: 0.9401
#
# Top 3 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6866, Precision: 0.9227, Recall: 0.9575, F1 Score: 0.9398
#
# Top 4 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6056, Precision: 0.9387, Recall: 0.9387, F1 Score: 0.9387
#
# Top 5 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6514, Precision: 0.9075, Recall: 0.9717, F1 Score: 0.9385
#
# Top 6 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6901, Precision: 0.9429, Recall: 0.9340, F1 Score: 0.9384
#
# Top 7 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6655, Precision: 0.9148, Recall: 0.9623, F1 Score: 0.9379
#
# Top 8 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.7113, Precision: 0.9515, Recall: 0.9245, F1 Score: 0.9378
#
# Top 9 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6690, Precision: 0.9186, Recall: 0.9575, F1 Score: 0.9376
#
# Top 10 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6514, Precision: 0.9186, Recall: 0.9575, F1 Score: 0.9376
#
# Top 11 Configuration:
# Config Details: {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6937, Precision: 0.9224, Recall: 0.9528, F1 Score: 0.9374
#
# Top 12 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6866, Precision: 0.9224, Recall: 0.9528, F1 Score: 0.9374
#
# Top 13 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6585, Precision: 0.9263, Recall: 0.9481, F1 Score: 0.9371
#
# Top 14 Configuration:
# Config Details: {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6197, Precision: 0.9000, Recall: 0.9764, F1 Score: 0.9367
#
# Top 15 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6901, Precision: 0.9426, Recall: 0.9292, F1 Score: 0.9359

# %%
# Print out the details of the top 15 configurations
for idx, result in enumerate(top_15_configs):
    config_details = result['config']
    print(f"Top {idx+1} Configuration:")
    print(f"Config Details: {config_details}")
    print(f"Test Accuracy: {result['test_accuracy']:.4f}, Precision: {result['precision']:.4f}, Recall: {result['recall']:.4f}, F1 Score: {result['f1_score']:.4f}\n")

# Plot accuracy and loss separately for each of the top 15 configurations
for idx, result in enumerate(top_15_configs):
    # Create a new figure for each configuration
    plt.figure(figsize=(12, 5))

    # Accuracy plot
    plt.subplot(1, 2, 1)
    plt.plot(result['history'].history['accuracy'], label='Train Accuracy')
    plt.plot(result['history'].history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'Configuration {idx+1} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='best')
    plt.grid(True)

    # Loss plot
    plt.subplot(1, 2, 2)
    plt.plot(result['history'].history['loss'], label='Train Loss')
    plt.plot(result['history'].history['val_loss'], label='Validation Loss')
    plt.title(f'Configuration {idx+1} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='best')
    plt.grid(True)

    # Adjust layout and show the plot
    plt.tight_layout()
    plt.show()
# Out:
# Top 1 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.7113, Precision: 0.9437, Recall: 0.9481, F1 Score: 0.9459
#
# Top 2 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6796, Precision: 0.9189, Recall: 0.9623, F1 Score: 0.9401
#
# Top 3 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6866, Precision: 0.9227, Recall: 0.9575, F1 Score: 0.9398
#
# Top 4 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6056, Precision: 0.9387, Recall: 0.9387, F1 Score: 0.9387
#
# Top 5 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6514, Precision: 0.9075, Recall: 0.9717, F1 Score: 0.9385
#
# Top 6 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6901, Precision: 0.9429, Recall: 0.9340, F1 Score: 0.9384
#
# Top 7 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6655, Precision: 0.9148, Recall: 0.9623, F1 Score: 0.9379
#
# Top 8 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.7113, Precision: 0.9515, Recall: 0.9245, F1 Score: 0.9378
#
# Top 9 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6690, Precision: 0.9186, Recall: 0.9575, F1 Score: 0.9376
#
# Top 10 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 128, 'dropout': 0.3, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6514, Precision: 0.9186, Recall: 0.9575, F1 Score: 0.9376
#
# Top 11 Configuration:
# Config Details: {'conv_layers': 1, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 64, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6937, Precision: 0.9224, Recall: 0.9528, F1 Score: 0.9374
#
# Top 12 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 64, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6866, Precision: 0.9224, Recall: 0.9528, F1 Score: 0.9374
#
# Top 13 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 2, 'dense_units': 64, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6585, Precision: 0.9263, Recall: 0.9481, F1 Score: 0.9371
#
# Top 14 Configuration:
# Config Details: {'conv_layers': 1, 'filters': 64, 'dense_layers': 1, 'dense_units': 64, 'dropout': 0.2, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.002, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6197, Precision: 0.9000, Recall: 0.9764, F1 Score: 0.9367
#
# Top 15 Configuration:
# Config Details: {'conv_layers': 2, 'filters': 32, 'dense_layers': 1, 'dense_units': 128, 'dropout': 0.1, 'epochs': 50, 'batch_size': 32, 'learning_rate': 0.001, 'activation': 'relu', 'optimizer': 'adam'}
# Test Accuracy: 0.6901, Precision: 0.9426, Recall: 0.9292, F1 Score: 0.9359
